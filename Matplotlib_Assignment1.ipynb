# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import random

# %% [markdown]
# ## Q1: Create two charts using list and dataframe.

# %%
mylist = [np.random.normal(40, 10, 1000)]

plt.hist(mylist, bins=30, color='skyblue', edgecolor='white')
plt.title('Histogram of Age', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show();

years = [2010, 2011, 2012, 2013, 2014, 2015, 2016]
categories = ['A', 'B', 'C', 'D', 'E']

df = pd.DataFrame({
    'date' : [2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'a'    : [5, 4, 6, 4, 5, 6, 7],
    'b'    : [3, 2, 3, 4, 3, 4, 5],
    'c'    : [1, 2, 2, 3, 3, 4, 4],
    'd'    : [4, 3, 4, 3, 2, 3, 4],
    'e'    : [2, 1, 2, 2, 1, 2, 3]
})

plt.stackplot(
    df['date'],
    [df['a'], df['b'], df['c'], df['d'], df['e']],
    labels=['a', 'b', 'c', 'd', 'e'], alpha=0.8
)

plt.title('Area Plot', fontsize=15)
plt.xlabel('Years', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.legend(loc='upper left')

plt.show();

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
data = pd.read_csv('final_cars_datasets.csv')

mark = data['mark'].value_counts().sort_values(ascending=False)[:7]

plt.pie(
    mark, labels=mark.index,
    autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors,
    shadow=True, radius=1, explode = [0.3,0.3,0.3,0.3,0.3,0.3,0.3]
)

plt.title('Distribution of Used Cars by Brand', fontsize=10)

plt.show();

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
data = pd.read_csv('Housing.csv')

plt.scatter(
    data['area'], data['price'],
    color='b', alpha=0.4, label='Houses', s=50
)
plt.show();

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
data = pd.read_csv('Housing.csv')

plt.scatter(
    data['area'], data['price'],
    color='b', alpha=0.4, label='Houses', s=50
)
plt.title('Relationship Between House Area and Price', fontsize=15, loc = 'left' , color='r' )
plt.xlabel('House Area', fontsize=16)
plt.ylabel('House Price', fontsize=16)
plt.show();

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors.

# %%
costs    = [random.randint(5000, 30000)  for i in range(12)]
benefits = [random.randint(10000, 50000) for i in range(12)]
revinews = [random.randint(3000, 30000) for i in range(12)]


months = [datetime(2022, i, 1) for i in range(1, 13)]

plt.plot(months, costs, marker='o', linestyle='--', color='r', label='Costs')
plt.plot(months, benefits, marker='o', linestyle='--', color='b', label='Benefits')
plt.plot(months, revinews, marker='o', linestyle='--', color='g', label='revinews')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%b %Y'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())
plt.gcf().autofmt_xdate()
plt.legend(loc = 'center left')
plt.show();

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10.

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))

x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

axs[0].plot(x, y1, color='r')
axs[0].set_title('Sin Plot')

axs[1].plot(x, y1, color='g')
axs[1].set_title('Sin Plot')


axs[2].plot(x, y1, color='c')
axs[2].set_title('Sin Plot')

plt.show();
